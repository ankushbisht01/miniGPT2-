# %% [markdown]
# # Data Exploration
# Initial exploration of the dataset.

# %%
# Out:
# Running cells with 'env (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/Users/ankushbisht/Documents/GPT2 from scratch/env/bin/python" -m pip install ipykernel -U --force-reinstall'
